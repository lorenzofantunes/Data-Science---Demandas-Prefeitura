# %%
import pandas as pd
from wordcloud import WordCloud
import nltk as nl
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3adbc50cd04f> in <module>()
#       1 import pandas as pd
# ----> 2 from wordcloud import WordCloud
#       3 import nltk as nl
#       4 import matplotlib.pyplot as plt
#       5 from nltk.corpus import stopwords
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ## Leitura e tratamento de dados

# %%
df = pd.read_csv('solicitacoes.csv', sep=';', encoding="utf-8")

# %%
df['descricao'].describe()

# %% [markdown]
# ### Verificando dados:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7695 entries, 0 to 7694
# Data columns (total 7 columns):
# abertura            7695 non-null object
# tipo                7695 non-null object
# solicitacao         7695 non-null object
# descricao           7019 non-null object
# tipo_solicitacao    7695 non-null object
# origem              7695 non-null object
# situacao            7695 non-null object
# dtypes: object(7)
# memory usage: 420.9+ KB

# %% [markdown]
# ### Verificando dados que possuem campo descrição como NaN

# %%
df[df['descricao'].isnull()]
# Out:
#         abertura                               tipo  \
# 7     2015-10-06              Maus tratos a animais
# 9     2015-10-06          Poda e Retirada de Árvore
# 12    2015-10-07                     Rua esburacada
# 14    2015-10-07                     Obra irregular
# 17    2015-10-08    Entulho na calçada/ Via pública
# 18    2015-10-13  Ocupação Irregular de Área Púlica
# 20    2015-10-13          Poda e Retirada de Árvore
# 22    2015-10-13                     Terreno baldio
# 25    2015-10-14                     Terreno baldio
# 26    2015-10-14     Não cumprimento de itinerários
# 27    2015-10-15                     Rua esburacada
# 28    2015-10-15  Ocupação Irregular de Área Púlica
# 32    2015-10-16       Iluminação Pública Irregular
# 34    2015-10-16       Iluminação Pública Irregular
# 35    2015-10-16       Iluminação Pública Irregular
# 36    2015-10-16       Iluminação Pública Irregular
# 38    2015-10-16       Iluminação Pública Irregular
# 39    2015-10-16                     Rua esburacada
# 40    2015-10-16       Iluminação Pública Irregular
# 41    2015-10-16       Iluminação Pública Irregular
# 43    2015-10-16       Iluminação Pública Irregular
# 45    2015-10-16       Iluminação Pública Irregular
# 46    2015-10-16       Iluminação Pública Irregular
# 47    2015-10-16       Iluminação Pública Irregular
# 48    2015-10-16       Iluminação Pública Irregular
# 51    2015-10-16       Iluminação Pública Irregular
# 53    2015-10-16       Iluminação Pública Irregular
# 56    2015-10-16           Estacionamento Irregular
# 57    2015-10-16       Iluminação Pública Irregular
# 59    2015-10-16          Vazamento de água potável
# ...          ...                                ...
# 5450  2017-03-27         Lei de Acesso a Informação
# 5496  2017-03-31         Lei de Acesso a Informação
# 5501  2017-04-02         Lei de Acesso a Informação
# 5738  2017-04-25         Lei de Acesso a Informação
# 5758  2017-04-26         Lei de Acesso a Informação
# 5772  2017-04-26         Lei de Acesso a Informação
# 5808  2017-05-02       Iluminação Pública Irregular
# 5826  2017-05-03         Lei de Acesso a Informação
# 5836  2017-05-04         Lei de Acesso a Informação
# 5999  2017-05-18         Lei de Acesso a Informação
# 6436  2017-06-25         Lei de Acesso a Informação
# 6544  2017-07-03         Lei de Acesso a Informação
# 6603  2017-07-07         Lei de Acesso a Informação
# 6798  2017-07-26         Lei de Acesso a Informação
# 6945  2017-08-09         Lei de Acesso a Informação
# 7046  2017-08-17         Lei de Acesso a Informação
# 7048  2017-08-17         Lei de Acesso a Informação
# 7062  2017-08-18         Lei de Acesso a Informação
# 7084  2017-08-21         Lei de Acesso a Informação
# 7121  2017-08-24         Lei de Acesso a Informação
# 7277  2017-09-11         Lei de Acesso a Informação
# 7305  2017-09-13         Lei de Acesso a Informação
# 7366  2017-09-19         Lei de Acesso a Informação
# 7367  2017-09-19         Lei de Acesso a Informação
# 7479  2017-10-03         Lei de Acesso a Informação
# 7613  2017-10-18         Lei de Acesso a Informação
# 7619  2017-10-18         Lei de Acesso a Informação
# 7647  2017-10-23         Lei de Acesso a Informação
# 7649  2017-10-23         Lei de Acesso a Informação
# 7652  2017-10-23         Lei de Acesso a Informação
#
#                                             solicitacao descricao  \
# 7     Cidadã alega que no endereço; Rua São Jorge, n...       NaN
# 9     PODA DE ÁRVORE NO ENDEREÇO; RUA VEREADOR CELSO...       NaN
# 12    Cidadã alega que no endereço; Rua 4, Bairro; L...       NaN
# 14    Cidadão reivindica referente no endereço; Rua ...       NaN
# 17    Solicita a retirada de entulhos no endereço; A...       NaN
# 18    A Sra. denuncia que há um muro construído de f...       NaN
# 20    A solicitante pede que seja feita a poda da ár...       NaN
# 22    Cidadã reivindica referente atrás do endereço;...       NaN
# 25    CIDADÃO REIVINDICA REFERENTE NO ENDEREÇO; AV I...       NaN
# 26    CIDADÃ REIVINDICA REFERENTE OS ONIBUS DA EMPRE...       NaN
# 27    O declarante relata que por consequência das r...       NaN
# 28    CIDADÃO REIVINDICA REFERENTE NO ENDEREÇO; ENTR...       NaN
# 32    Solicita reposição de lampada no endereço; Rua...       NaN
# 34    Cidadão alega que no endereço; Av\r\nTeodoro M...       NaN
# 35    REPOSIÇÃO DE LAMPADA NO\r\nENDEREÇO: RUA EVARI...       NaN
# 36    Reposição de lâmpada no\r\nendereço;Av Jose Ma...       NaN
# 38    Falta de luz na rua Tiradentes 3374,\r\nno cen...       NaN
# 39    CIDADÃ ALEGA QUE NO ENDEREÇO; RUA FRANCISCO BR...       NaN
# 40    Solicita reposição de lâmpada na\r\nRua LUIZ A...       NaN
# 41    REPOSIÇÃO DE LAMPADA NO\r\nENDEREÇO; RUA TIRAD...       NaN
# 43    Reposição de lâmpada no endereço;\r\nRua 6, BL...       NaN
# 45    Reposição de lâmpada no endereço;\r\nRua Alvar...       NaN
# 46    solicita reposição de lâmpada na rua\r\nAv 25 ...       NaN
# 47    REPOSIÇÃO DE ILUMINAÇÃO\r\nPÚBLICA NO ENDEREÇO...       NaN
# 48    Solicita reposição de lâmpada na\r\nrua Marcíl...       NaN
# 51    REPOSIÇÃO DE LAMPADA NO\r\nENDEREÇO; AV REPUBL...       NaN
# 53    Reposição de lâmpada no endereço:\r\nRua 1,n°2...       NaN
# 56    Solicita reposição na rua Travessa\r\n5 Carlos...       NaN
# 57    REPOSIÇÃO DE LÂMPADA NO\r\nENDEREÇO; RUA FELIC...       NaN
# 59    CIDADÃ ALEGA QUE NO ENDEREÇO; RUA ANTONIO DOS ...       NaN
# ...                                                 ...       ...
# 5450  Boa tarde\r\nDe acordo com a Lei de Acesso Ã  ...       NaN
# 5496  zccMZY http://www.LnAJ7K8QSpkiStk3sLL0hQP6MO2w...       NaN
# 5501  Precisamos saber a data em que foi paga as not...       NaN
# 5738  Prezados, sou pesquisadora da Universidade Fed...       NaN
# 5758  OlÃ¡, gostaria de saber se Pelotas possui um P...       NaN
# 5772   OlÃ¡, gostaria de saber onde posso encontrar ...       NaN
# 5808  Cidadão solicita reposição de lampada na Trave...       NaN
# 5826  Nome de todas as pessoas que receberam precatÃ...       NaN
# 5836          Contra cheque dos meses de marÃ§o e abril       NaN
# 5999  dUEEvX http://www.LnAJ7K8QSpkiStk3sLL0hQP6MO2w...       NaN
# 6436  Prezado(a) Senhor(a), \r\nConsiderando que nÃ£...       NaN
# 6544  Com o intuito de ter assegurado o direito fund...       NaN
# 6603  Prezados, boa noite.\r\nEm atenÃ§Ã£o Ã  NotÃ­c...       NaN
# 6798  Sou mestranda em Direito e JustiÃ§a Social na ...       NaN
# 6945  Prezados, Gostaria de solicitar uma listagem d...       NaN
# 7046  OlÃ¡, gostaria de saber se o Plano Municipal d...       NaN
# 7048  OlÃ¡, gostaria de solicitar uma cÃ³pia digital...       NaN
# 7062  Ola! Gostaria de saber se o Plano Diretor de P...       NaN
# 7084  Boa tarde. FaÃ§o parte de um time de pesquisa ...       NaN
# 7121  Bom dia,\r\n\r\nGostaria de receber o organogr...       NaN
# 7277  V8SBPJ http://www.FyLitCl7Pf7ojQdDUOLQOuaxTXbj...       NaN
# 7305                                                          NaN
# 7366  De acordo com a lei 12.527 solicito o que se s...       NaN
# 7367  Prezados, boa tarde.\r\nEm atenÃ§Ã£o ao Projet...       NaN
# 7479  Prezados, boa tarde.\r\nEm atenÃ§Ã£o ao Projet...       NaN
# 7613  Gostaria de saber se a rua Francisco Brochado ...       NaN
# 7619  Gostaria de saber o nÃºmero de cargos em comis...       NaN
# 7647                                                  1       NaN
# 7649                                                  1       NaN
# 7652                                                  1       NaN
#
#             tipo_solicitacao      origem situacao
# 7                 Reclamação  Presencial  Fechado
# 9     Solicitação de Serviço  Presencial  Fechado
# 12    Solicitação de Serviço  Presencial  Fechado
# 14                Reclamação  Presencial  Fechado
# 17    Solicitação de Serviço  Presencial  Fechado
# 18                  Denuncia  Presencial  Fechado
# 20    Solicitação de Serviço  Presencial  Fechado
# 22                Reclamação  Presencial  Fechado
# 25                Reclamação    Telefone  Fechado
# 26                Reclamação    Telefone  Fechado
# 27                Reclamação    Telefone  Fechado
# 28                Reclamação    Telefone  Fechado
# 32    Solicitação de Serviço    Telefone  Fechado
# 34    Solicitação de Serviço  Presencial  Fechado
# 35    Solicitação de Serviço  Presencial  Fechado
# 36    Solicitação de Serviço    Telefone  Fechado
# 38    Solicitação de Serviço    Telefone  Fechado
# 39    Solicitação de Serviço    Telefone  Fechado
# 40    Solicitação de Serviço    Telefone  Fechado
# 41    Solicitação de Serviço  Presencial  Fechado
# 43    Solicitação de Serviço    Telefone  Fechado
# 45    Solicitação de Serviço    Telefone  Fechado
# 46    Solicitação de Serviço    Telefone  Fechado
# 47    Solicitação de Serviço    Telefone  Fechado
# 48    Solicitação de Serviço    Telefone  Fechado
# 51    Solicitação de Serviço    Telefone  Fechado
# 53    Solicitação de Serviço    Telefone  Fechado
# 56    Solicitação de Serviço    Telefone  Fechado
# 57    Solicitação de Serviço  Presencial  Fechado
# 59    Solicitação de Serviço    Telefone  Fechado
# ...                      ...         ...      ...
# 5450                     LAI         Lai  Fechado
# 5496                     LAI         Lai  Fechado
# 5501                     LAI         Lai   Aberto
# 5738                     LAI         Lai   Aberto
# 5758                     LAI         Lai  Fechado
# 5772                     LAI         Lai  Fechado
# 5808  Solicitação de Serviço    Telefone   Aberto
# 5826                     LAI         Lai  Fechado
# 5836                     LAI         Lai  Fechado
# 5999                     LAI         Lai  Fechado
# 6436                     LAI         Lai  Fechado
# 6544                     LAI         Lai  Fechado
# 6603                     LAI         Lai  Fechado
# 6798                     LAI         Lai  Fechado
# 6945                     LAI         Lai  Fechado
# 7046                     LAI         Lai  Fechado
# 7048                     LAI         Lai  Fechado
# 7062                     LAI         Lai  Fechado
# 7084                     LAI         Lai   Aberto
# 7121                     LAI         Lai  Fechado
# 7277                     LAI         Lai  Fechado
# 7305                     LAI         Lai  Fechado
# 7366                     LAI         Lai   Aberto
# 7367                     LAI         Lai  Fechado
# 7479                     LAI         Lai  Fechado
# 7613                     LAI         Lai   Aberto
# 7619                     LAI         Lai  Fechado
# 7647                     LAI         Lai  Fechado
# 7649                     LAI         Lai  Fechado
# 7652                     LAI         Lai  Fechado
#
# [676 rows x 7 columns]

# %% [markdown]
# ### Retirando esses dados

# %%
df = df[df['descricao'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7019 entries, 0 to 7694
# Data columns (total 7 columns):
# abertura            7019 non-null object
# tipo                7019 non-null object
# solicitacao         7019 non-null object
# descricao           7019 non-null object
# tipo_solicitacao    7019 non-null object
# origem              7019 non-null object
# situacao            7019 non-null object
# dtypes: object(7)
# memory usage: 438.7+ KB

# %% [markdown]
# ### Setando o texto das solicitações para minúsculo

# %%
df['solicitacoes'] = df.solicitacao.str.lower()
del df['solicitacao']

# %% [markdown]
# ## Análise dos problemas da cidade a partir do texto das solicitações

# %% [markdown]
# ### Transformando texto em vetor de palavras

# %%
words = []
for p in df.solicitacoes.apply(lambda sol: sol.split(" ")):
    for w in p:
         words.append(w)
words = pd.Series(words)
words.head()
# Out:
# 0         obra
# 1    irregular
# 2         esta
# 3        sendo
# 4    executada
# dtype: object

# %% [markdown]
# ### Removendo stop words

# %%
filtered_words = [word for word in words if word not in stopwords.words('portuguese')]

# %%
for word in filtered_words[0:10]:
    print(word)
# Out:
# obra
# irregular
# sendo
# executada
# rua
# alziro
# zarur
# n°554.
# obra
# projeto,

# %% [markdown]
# ### Frequência de cada palavra no texto - StopWords, utilizando o NLTK

# %%
freq = nl.FreqDist(filtered_words)

# %%
freq.most_common(100)
# Out:
# [(u'rua', 5754),
#  (u'', 4081),
#  (u'cidad\xe3', 2651),
#  (u'cidad\xe3o', 2404),
#  (u'solicita', 2161),
#  (u'pede', 1593),
#  (u'n\xba', 1564),
#  (u'frente', 1359),
#  (u'endere\xe7o;', 1303),
#  (u'bairro', 1199),
#  (u'denuncia', 1176),
#  (u'\xe9', 1111),
#  (u'pois', 967),
#  (u'lampada', 823),
#  (u'esquina', 801),
#  (u'bairro;', 783),
#  (u'\xe1gua', 747),
#  (u'alega', 691),
#  (u'bairro:', 676),
#  (u'segundo', 649),
#  (u'casa', 646),
#  (u'lado', 612),
#  (u'existe', 586),
#  (u'tr\xeas', 573),
#  (u'fiscaliza\xe7\xe3o', 561),
#  (u'pr\xf3ximo', 546),
#  (u'troca', 530),
#  (u'reposi\xe7\xe3o', 507),
#  (u'poda', 493),
#  (u'ilumina\xe7\xe3o', 444),
#  (u'n\xfamero', 442),
#  (u'pedido', 438),
#  (u'av.', 438),
#  (u'lixo', 424),
#  (u'limpeza', 423),
#  (u'terreno', 411),
#  (u'devido', 410),
#  (u'av', 396),
#  (u'local', 380),
#  (u'mesma', 352),
#  (u'fragata', 343),
#  (u'moradores', 324),
#  (u'arvore', 312),
#  (u'esgoto', 300),
#  (u'moradora', 292),
#  (u'santa', 288),
#  (u'cal\xe7ada', 287),
#  (u'dia', 287),
#  (u'fica', 286),
#  (u'areal', 281),
#  (u'urg\xeancia', 278),
#  (u'poste', 267),
#  (u'reclama', 267),
#  (u'pra\xe7a', 261),
#  (u'vendas', 260),
#  (u'cohab', 259),
#  (u'reparo', 255),
#  (u'morador', 253),
#  (u'avenida', 252),
#  (u'dr.', 249),
#  (u'sim\xf5es', 239),
#  (u'-', 238),
#  (u'obra', 237),
#  (u'gostaria', 236),
#  (u'fragata.', 236),
#  (u'urg\xeancia.', 231),
#  (u'onde', 228),
#  (u'\xf4nibus', 226),
#  (u'dias', 216),
#  (u'ter', 216),
#  (u'laranjal', 213),
#  (u'vazamento', 209),
#  (u'dois', 208),
#  (u'ser', 207),
#  (u'centro', 207),
#  (u'posto', 206),
#  (u'fragata,', 205),
#  (u'centro.', 205),
#  (u'areal.', 205),
#  (u'existir', 205),
#  (u'estar', 200),
#  (u'via', 196),
#  (u'provid\xeancias.', 196),
#  (u'francisco', 193),
#  (u'sendo', 192),
#  (u'condi\xe7\xf5es', 189),
#  (u'visto', 189),
#  (u'local.', 188),
#  (u'centro,', 188),
#  (u'toda', 187),
#  (u'baldio', 186),
#  (u'endere\xe7o:', 183),
#  (u'irregular', 182),
#  (u'propriet\xe1rio', 182),
#  (u'necessita', 178),
#  (u'parada', 178),
#  (u'muitos', 176),
#  (u'meio', 176),
#  (u'vendas.', 175),
#  (u'l\xe2mpada', 175)]

# %% [markdown]
# ### Ao analizar as 100 palavras com maior frequência, é perceptivel que palavras pequenas não dizem muito sobre o contexto. Ex: ser, ter, -, dia, av., av.
#
# ### A solução encontrada para esse obstáculo foi utilzar análizar o contexto pela frequência mas com um tamanho mínimo de palavra.

# %%
words_f = [w for w in set(filtered_words) if len(w) > 3 and freq[w] > 200]
words_f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e9343c3359b> in <module>()
# ----> 1 words_f = [w for w in set(filtered_words) if len(w) > 3 and freq[w] > 200]
#       2 words_f
#
# NameError: name 'filtered_words' is not defined

# %% [markdown]
# ### WORDCLOUD das palavras mais utilizadas, obs: o tamanho da palavra na figura não quer dizer que a mesma é mais frequente

# %%
wordcloud = WordCloud(relative_scaling = 1.0).generate(' '.join(words_f))
plt.figure(figsize=(14,14))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Gráfico com as palavras mais comuns no texto e quantas repetições foram encontradas na mesma

# %%
words = [x[0] for x in freq.most_common(75) if(len(x[0]) > 3) and freq[x[0]] > 200]
values = [int(x[1]) for x in freq.most_common(75) if(len(x[0]) > 3) and freq[x[0]] > 200]
plt.figure(figsize=(14, 30))
mybar = plt.barh(words, values, color='green', alpha=0.4)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Word Frequency Chart')
plt.show()

# %% [markdown]
# ## Unificamos as palavras mais frequêntes com o seu possível contexto, assim dando uma melhor ideia do tipo de problemas enfrentados na cidade.

# %%
problems = ['limpeza', 'poda', 'saneamento', 'iluminacao']
counts = [freq['limpeza'] + freq['lixo'], freq['poda']+freq['arvore'],
          freq['água'] + freq['esgoto'] + freq['vazamento'],
          freq['iluminação'] + freq['lampada'] + freq['poste']]
plt.figure(figsize=(14, 8))
mybar = plt.barh(problems, counts, color='green', alpha=0.4)
plt.xlabel('Frequency')
plt.ylabel('Problem')
plt.title('Problem Frequency Chart')
plt.show()

# %% [markdown]
# ## RESULTADO
# ### Na lista das palavras mais frequentes, é possivel verificar a presença de bairros, assim podendo relaciona-los com um grande número de ocorrências. São eles: Centro, Fragata, Laranjal Areal e Três Vendas.
#
# ### Os problemas mais comuns apontados pelo estudo são de limpeza (relacionados a palavra limpeza, lixo), poda ( relacionados as palavras poda e árvore), sanêamento ( relacionados as palavras água, esgoto e vazamênto) e iluminação (relacionados as palavras iluminação, lampada e poste).
#
# ### Lugares que devem ter atenção além da descrição e bairros (praças, terrenos e ônibus)

# %% [markdown]
# ## Abaixo tentamos confirmar os dados retirados da descrição, utilizando outros campos

# %% [markdown]
# ### Validação dos dados retirados a partir da solicitação:

# %%
df.tipo.value_counts()[0:10]
# Out:
# Iluminação Pública Irregular     1572
# Poda e Retirada de Árvore         554
# Limpeza Urbana                    316
# Foco de Dengue                    315
# Rivindicação Ouvidoria            295
# Terreno baldio                    291
# Obra irregular                    269
# Buraco na via NÃO pavimentada     209
# Vazamento de água potável         188
# Buraco na via pavimentada         165
# Name: tipo, dtype: int64

# %%
df.descricao.value_counts()[0:5]
# Out:
# Centro                                                                                                  1337
# Fragata                                                                                                 1187
# Três Vendas                                                                                              990
# Areal                                                                                                    934
# Laranjal                                                                                                 483
# Name: descricao, dtype: int64

# %% [markdown]
# ## Resultados finais da análise dos dados a partir da descrição da solicitação:
# ### A partir dos dados das solicitações, foi possível a reconstrução e verificação de outros dados informados pela prefeitura.
