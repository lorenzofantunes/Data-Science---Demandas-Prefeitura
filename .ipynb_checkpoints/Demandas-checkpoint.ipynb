# %% [markdown]
# # Limpando os dados

# %%
import csv
import pandas as pd

data = []
with open('demandas.csv', 'r') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=';', quotechar='"')
    data = list(spamreader)
    for x in range(len(data)):
        data[x] = [y.replace(";", ",").rstrip() for y in data[x]]        

df = pd.DataFrame(data[1:], columns = data[0])
df['abertura'] =  pd.to_datetime(df['abertura'], format='%Y-%m-%d')

df.loc[df['origem'] == 'Facebook - 1', 'origem'] = 'Facebook'
df.loc[df['origem'] == 'Facebook - 2', 'origem'] = 'Facebook'

# %% [markdown]
# # Entendendo os Dados
# 1. **OS DADOS NÃO FORAM ANONIMIZADOS** existem chamados que possuem dados pessoais das pessoas.
# 2. Existem vários chamados de "teste" ou com dados estranhos como links ou códigos (provavlemente bots), além de chamados repetidos
# 3. Pedidos da categoria de Lei de Acesso a Informação (LAI) existem vários pedidos de dados para teses

# %%
df.describe()
# Out:
#                    abertura                          tipo  \
# count                  7695                          7695
# unique                  535                            97
# top     2017-02-06 00:00:00  Iluminação Pública Irregular
# freq                     52                          1664
# first   2015-10-02 00:00:00                           NaN
# last    2017-10-25 00:00:00                           NaN
#
#                                               solicitacao descricao  \
# count                                                7695      7695
# unique                                               7316        40
# top     moradores denuncia uma casa que esta para vend...    Centro
# freq                                                   43      1337
# first                                                 NaN       NaN
# last                                                  NaN       NaN
#
#               tipo_solicitacao    origem situacao
# count                     7695      7695     7695
# unique                       6        10        2
# top     Solicitação de Serviço  Telefone  Fechado
# freq                      4267      4709     6043
# first                      NaN       NaN      NaN
# last                       NaN       NaN      NaN

# %% [markdown]
# ## Abertura
# Dia em que foi aberto o chamado
#
# ## Solicitação
#
# ## Descrição
#
# ## Origem
#
# ## Solicitação

# %% [markdown]
# ## Tipo de Solicitação
# LAI - Lei de Acesso a Informação

# %%
print("Tipos de Solicitação")
print(df['tipo_solicitacao'].value_counts())
print("\n")

#for row in df[df['tipo_solicitacao'] == 'Audiência Pública']['solicitacao']:
#    print(row + "\n")
# Out:
# Tipos de Solicitação
# Solicitação de Serviço    4267
# Denuncia                  1730
# Reclamação                1298
# Informação                 218
# LAI                        117
# Audiência Pública           65
# Name: tipo_solicitacao, dtype: int64

# %% [markdown]
# ## Tipo

# %% [markdown]
# # Hipóteses

# %% [markdown]
# ## Origem dos chamados

# %%
# %matplotlib inline

#import matplotlib.pyplot as plt
from matplotlib.pyplot import *

origem = df['origem'].value_counts()
#origem['Facebook'] = origem['Facebook - 1'] + origem['Facebook - 2']
#del(origem['Facebook - 1'])
#del(origem['Facebook - 2'])
origem = origem.sort_values()
print(origem)
# Out:
# Colab                         1
# Radio escuta                  1
# Instagram                     3
# Email                        49
# Audiências Públicas          69
# Lai                         113
# Portal da transparência     306
# Presencial                 1113
# Facebook                   1331
# Telefone                   4709
# Name: origem, dtype: int64

# %% [markdown]
# #### Quantidade de chamados por tipo

# %%
origem.plot(kind="bar")

# %% [markdown]
# #### Quantidade de chamados por tipo no ano de 2017

# %%
df[df['abertura'] >= '2017-01-01']['origem'].value_counts().sort_values().plot(kind="bar")

# %% [markdown]
# ### Qual a visão geral do atendimento entre Facebook, Telefone, Presencial e Portal da Transparência?

# %%
facebook = df.loc[df['origem'] == 'Facebook']['abertura'].value_counts().sort_index()
telefone = df.loc[df['origem'] == 'Telefone']['abertura'].value_counts().sort_index()
presencial = df.loc[df['origem'] == 'Presencial']['abertura'].value_counts().sort_index()
transparencia = df.loc[df['origem'] == 'Portal da transparência']['abertura'].value_counts().sort_index()

#print(facebook.sum()/)
for x in zip([facebook, telefone, presencial, transparencia], ["facebook", "telefone", "presencial", "transparencia"]):
    #media = x[0].count()/df.count().abertura    
    media = x[0].sum()/len(df.abertura.unique())
    print("Média de atendimentos por " + x[1] + ": " + str(media))
# Out:
# 535
# Média de atendimentos por facebook: 2.4878504672897197
# Média de atendimentos por telefone: 8.801869158878505
# Média de atendimentos por presencial: 2.080373831775701
# Média de atendimentos por transparencia: 0.5719626168224299

# %%
fig, ax = subplots()

facebook.plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
telefone.plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
presencial.plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
transparencia.plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
ax.legend(["Facebook", "Telefone", "Presencial", "Transparencia"]);

# %% [markdown]
# ### Qual a visão geral do atendimento entre Facebook, Telefone e Presencial no ultimo ano?

# %%
for x in zip([facebook.loc[facebook.index >= '2017-01-01'], telefone.loc[telefone.index >= '2017-01-01'], presencial.loc[presencial.index >= '2017-01-01'], transparencia.loc[transparencia.index >= '2017-01-01']], ["facebook", "telefone", "presencial", "transparencia"]):
    #media = x[0].count()/df[df.abertura >= '2017-01-01'].count().abertura    
    #media = x[0].count()/df.count().abertura    
    media = x[0].sum()/len(df[df.abertura >= '2017-01-01'].abertura.unique())    
    print("Média de atendimentos por " + x[1] + " no ultimo ano: " + str(media))

print("\n")
#for x in zip([facebook.loc['2016-01-01' <= facebook.index  < '2017-01-01'], telefone.loc[telefone.index >= '2016-01-01' and telefone.index < '2017-01-01'], presencial.loc[presencial.index >= '2016-01-01' and presencial.index < '2017-01-01'], transparencia.loc[transparencia.index >= '2016-01-01' and transparencia.index < '2017-01-01']], ["facebook", "telefone", "presencial", "transparencia"]):
for x in zip([facebook.loc[('2016-01-01' <= facebook.index) &  (facebook.index < '2017-01-01')], telefone.loc[('2016-01-01' <= telefone.index) &  (telefone.index < '2017-01-01')], presencial.loc[('2016-01-01' <= presencial.index) &  (presencial.index < '2017-01-01')], transparencia.loc[('2016-01-01' <= transparencia.index) &  (transparencia.index < '2017-01-01')]], ["facebook", "telefone", "presencial", "transparencia"]):    
    media = x[0].sum()/len(df[('2016-01-01' <= df.abertura) & (df.abertura < '2017-01-01')].abertura.unique())    
    print("Média de atendimentos por " + x[1] + " em 2016: " + str(media))
# Out:
# Média de atendimentos por facebook no ultimo ano: 3.547169811320755
# Média de atendimentos por telefone no ultimo ano: 7.278301886792453
# Média de atendimentos por presencial no ultimo ano: 2.1367924528301887
# Média de atendimentos por transparencia no ultimo ano: 1.4433962264150944
#
#
# Média de atendimentos por facebook em 2016: 1.89272030651341
# Média de atendimentos por telefone em 2016: 9.96551724137931
# Média de atendimentos por presencial em 2016: 1.9425287356321839
# Média de atendimentos por transparencia em 2016: 0.0

# %% [markdown]
# ### Chamados acumulados no geral

# %%
fig, ax = subplots()
facebook.cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
telefone.cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
presencial.cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
transparencia.cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
ax.legend(["Facebook", "Telefone", "Presencial", "Transparencia"]);

# %% [markdown]
# ### Chamados acumulados em 2017

# %%
fig, ax = subplots()
facebook.loc[facebook.index >= '2017-01-01'].cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
telefone.loc[telefone.index >= '2017-01-01'].cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
presencial.loc[presencial.index >= '2017-01-01'].cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
transparencia.loc[transparencia.index >= '2017-01-01'].cumsum().plot(kind="line", figsize=(20, 10), fontsize=20, legend=True, ax=ax)
ax.legend(["Facebook", "Telefone", "Presencial", "Transparencia"]);

# %%
print(facebook[facebook.index >= '2017-01-01'].sum())
print(presencial[presencial.index >= '2017-01-01'].sum())
# Out:
# 752
# 453

# %% [markdown]
# ## Comparar quantidade de chamados por bairro durante as diferentes gestões

# %%
df.descricao.value_counts().sort_values().plot(kind="bar", figsize=(20, 10), fontsize=20)

# %%
df[df['abertura'] >= '2017-01-01'].descricao.value_counts().sort_values().plot(kind="bar", figsize=(20, 10), fontsize=20)

# %%
time = df['descricao'] == 'Centro'
df[time & (df['abertura'] >= '2017-01-01')].origem.value_counts().sort_values().plot(kind="bar", figsize=(20, 3), fontsize=20)

# %%
time = df['descricao'] == 'Fragata'
df[time & (df['abertura'] >= '2017-01-01')].origem.value_counts().sort_values().plot(kind="bar", figsize=(20, 3), fontsize=20)

# %%
time = df['descricao'] == 'Três Vendas'
df[time & (df['abertura'] >= '2017-01-01')].origem.value_counts().sort_values().plot(kind="bar", figsize=(20, 3), fontsize=20)

# %%
time = df['descricao'] == 'Areal'
df[time & (df['abertura'] >= '2017-01-01')].origem.value_counts().sort_values().plot(kind="bar", figsize=(20, 3), fontsize=20)

# %% [markdown]
# ## Dengue ocorre em maior quantidade nos bairros pobres?? (Existem dados relacionado a "riqueza" dos bairros?)

# %%
df[df['tipo'] == "Foco de Dengue"].descricao.value_counts()
# Out:
# Centro                     62
# Laranjal                   58
# Fragata                    52
# Areal                      33
#                            32
# Três Vendas                31
# Porto                       8
# Cohab Guabiroba             7
# Simões Lopes                6
# Navegantes II               5
# Nossa Senhora de Fátima     5
# Cohab Tablada               5
# Lindóia                     5
# Balsa                       5
# Arco-Íris                   3
# Cruzeiro                    3
# Cohab Lindóia               3
# Zona Rural                  2
# Bom Jesus                   2
# Sítio Floresta              2
# Pestano                     2
# Balneário dos Prazeres      2
# Cohab Fragata               2
# Navegantes I                2
# Navegantes III              1
# Castilhos                   1
# Vila Princesa               1
# Dunas                       1
# Getúlio Vargas              1
# Santos Dumont               1
# Sanga Funda                 1
# Colônia                     1
# Colônia Z-3                 1
# Cohab Pestano               1
# Name: descricao, dtype: int64

# %%
df['tipo'].value_counts().head(10).iloc[::-1].plot(kind="barh", figsize=(7, 5), fontsize=15)
#problemas = problemas[problemas['descricao'] != 'Centro'][problemas['descricao'] !=  'Fragata'][problemas['descricao'] !=  'Três Vendas'][problemas['descricao'] !=  'Areal'][problemas['descricao'] !=  'Laranjal'][problemas['descricao'] !=  '']
#problemas['tipo'].value_counts().head(10).iloc[::-1].plot(kind="barh", figsize=(5, 5), fontsize=15)

# %%
import matplotlib.pyplot as plt

results = []
bairros = []
valores = []

for bairro in df.descricao.unique():
    iluminacao = df[(df['tipo'] == "Iluminação Pública Irregular") & (df['descricao'] == bairro)]
    #print(df[df['descricao'] == bairro].abertura.count())
    #print(iluminacao['descricao'].count())
    iluminacao = (iluminacao['descricao'].count()/df[df['descricao'] == bairro].abertura.count())
    results.append([bairro, iluminacao])
#results.sort(key=lambda tup: tup[1], reverse=True)  # sorts in place
#print(results)

bolinha = np.arange(len(results))

for x in results:    
    bairros.append(str(x[0]))
    valores.append(str(x[1]))
plt.bar(bairros, valores)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-297-17bea49e8f21> in <module>()
#      17     bairros.append(str(x[0]))
#      18     valores.append(str(x[1]))
# ---> 19 plt.bar(bairros, valores)
#      20 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in <listcomp>(.0)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %% [markdown]
# ## Existem tipos de problemas que são associados a bairros específicos? NÃO

# %%
problemas = df.copy()
# Remove os bairros que mais aparecem para ver se existia algum padrão dos outros bairros
problemas = problemas[problemas['descricao'] != 'Centro'][problemas['descricao'] !=  'Fragata'][problemas['descricao'] !=  'Três Vendas'][problemas['descricao'] !=  'Areal'][problemas['descricao'] !=  'Laranjal'][problemas['descricao'] !=  '']
problemas['tipo'].value_counts().head(10).iloc[::-1].plot(kind="barh", figsize=(8, 5), fontsize=15)
# Out:
# /home/lorenzo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
problemas = df.copy()
# Remove os bairros que mais aparecem para ver se existia algum padrão dos outros bairros
problemas1 = problemas[problemas['descricao'] != 'Centro']]
problemas1['tipo'].value_counts().head(10).iloc[::-1].plot(kind="barh", figsize=(8, 5), fontsize=15)

# %%
indexes = problemas.tipo.value_counts().head().index
for problema in indexes:    
    #print(problema + ": " + str(df[df['tipo'] == problema].descricao.value_counts().head(6).describe()))
    print(problema + ": " + str(problemas[problemas['tipo'] == problema].descricao.value_counts().quantile(q=0.75)))
    print(problemas[problemas['tipo'] == problema].descricao.value_counts())
    #print(df[df['tipo'] == problema].descricao.value_counts().head(6))
    print("\n\n")
# Out:
# Iluminação Pública Irregular: 26.0
# Simões Lopes               46
# Porto                      40
# Cohab Tablada              35
# Cohab Fragata              35
# Balneário dos Prazeres     31
# Pestano                    29
# Dunas                      28
# Nossa Senhora de Fátima    26
# Sítio Floresta             23
# Sanga Funda                22
# Navegantes II              18
# Vila Princesa              18
# Cohab Lindóia              17
# Arco-Íris                  16
# Obelisco                   16
# Cohab Guabiroba            15
# Lindóia                    12
# Py Crespo                  11
# Getúlio Vargas             10
# Bom Jesus                  10
# Cruzeiro                    9
# Balsa                       9
# Navegantes I                6
# Cohabpel                    5
# Zona Rural                  4
# Zona Norte                  4
# Colônia                     2
# Castilhos                   1
# Cohab Pestano               1
# Name: descricao, dtype: int64
#
#
#
# Poda e Retirada de Árvore: 8.0
# Porto                      21
# Simões Lopes               19
# Nossa Senhora de Fátima    15
# Cohab Tablada              12
# Cohab Lindóia              11
# Cohab Fragata              11
# Navegantes II               8
# Balneário dos Prazeres      8
# Arco-Íris                   7
# Obelisco                    6
# Cohab Guabiroba             6
# Sanga Funda                 4
# Cruzeiro                    4
# Pestano                     4
# Navegantes I                4
# Lindóia                     3
# Sítio Floresta              3
# Bom Jesus                   3
# Getúlio Vargas              3
# Py Crespo                   3
# Zona Rural                  2
# Balsa                       2
# Cohab Pestano               1
# Vila Princesa               1
# Praias                      1
# Name: descricao, dtype: int64
#
#
#
# Limpeza Urbana: 6.0
# Nossa Senhora de Fátima    10
# Sítio Floresta             10
# Cohab Tablada               9
# Simões Lopes                9
# Balneário dos Prazeres      9
# Porto                       7
# Cruzeiro                    6
# Dunas                       6
# Arco-Íris                   6
# Cohab Fragata               5
# Bom Jesus                   3
# Cohab Lindóia               3
# Vila Princesa               3
# Cohab Guabiroba             2
# Lindóia                     2
# Pestano                     2
# Sanga Funda                 2
# Navegantes I                2
# Py Crespo                   2
# Obelisco                    2
# Navegantes II               2
# Zona Norte                  1
# Cohabpel                    1
# Getúlio Vargas              1
# Castilhos                   1
# Balsa                       1
# Name: descricao, dtype: int64
#
#
#
# Buraco na via NÃO pavimentada: 5.0
# Sanga Funda                13
# Vila Princesa               7
# Balneário dos Prazeres      6
# Bom Jesus                   6
# Sítio Floresta              6
# Cohab Tablada               5
# Simões Lopes                5
# Navegantes II               5
# Pestano                     3
# Dunas                       3
# Arco-Íris                   3
# Getúlio Vargas              3
# Nossa Senhora de Fátima     3
# Castilhos                   2
# Porto                       2
# Py Crespo                   2
# Zona Rural                  1
# Zona Norte                  1
# Cohab Fragata               1
# Lindóia                     1
# Cruzeiro                    1
# Navegantes I                1
# Cohab Pestano               1
# Colônia Z-3                 1
# Name: descricao, dtype: int64
#
#
#
# Foco de Dengue: 5.0
# Porto                      8
# Cohab Guabiroba            7
# Simões Lopes               6
# Cohab Tablada              5
# Lindóia                    5
# Nossa Senhora de Fátima    5
# Balsa                      5
# Navegantes II              5
# Cohab Lindóia              3
# Cruzeiro                   3
# Arco-Íris                  3
# Cohab Fragata              2
# Bom Jesus                  2
# Navegantes I               2
# Pestano                    2
# Balneário dos Prazeres     2
# Zona Rural                 2
# Sítio Floresta             2
# Colônia                    1
# Navegantes III             1
# Vila Princesa              1
# Colônia Z-3                1
# Dunas                      1
# Santos Dumont              1
# Castilhos                  1
# Sanga Funda                1
# Getúlio Vargas             1
# Cohab Pestano              1
# Name: descricao, dtype: int64

# %% [markdown]
# ## O que as pessoas se preocupam em bairros diferentes?

# %% [markdown]
# ## SANEP

# %%
Vazamento de água potável
# Out:
#   File "<ipython-input-21-f9729bda5199>", line 1
#     Vazamento de água potável
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Chamados resolvidos ou não?

# %%
total_chamados2015 = df[(df.abertura >= '2015-01-01') & (df.abertura < '2016-01-01')].abertura.count()
total_chamados2016 = df[(df.abertura >= '2016-01-01') & (df.abertura < '2017-01-01')].abertura.count()
total_chamados2017 = df[(df.abertura >= '2017-01-01')].abertura.count()

print("Total chamados 2015: " + str(total_chamados2015))
print("Total chamados 2016: " + str(total_chamados2016))
print("Total chamados 2017: " + str(total_chamados2017))                        
print()

outrosTotal = [0, 0, 0]
outrosAbertos = [0, 0, 0]
for bairro in df.descricao.unique():
    if bairro != "" and df[df.descricao == bairro].abertura.count() > 200:        
        print(bairro + ": " + str(df[(df.abertura >= '2017-01-01') & (df.descricao == bairro) & (df.situacao == "Aberto")].abertura.count()/df[(df.abertura >= '2017-01-01') & (df.descricao == bairro)].abertura.count()))
        print(bairro + ": " + str(df[(df.abertura >= '2016-01-01') & (df.abertura < '2017-01-01') & (df.descricao == bairro) & (df.situacao == "Aberto")].abertura.count()/df[(df.abertura >= '2016-01-01') & (df.abertura < '2017-01-01') & (df.descricao == bairro)].abertura.count()))
        print(bairro + ": " + str(df[(df.abertura >= '2015-01-01') & (df.abertura < '2016-01-01') & (df.descricao == bairro) & (df.situacao == "Aberto")].abertura.count()/df[(df.abertura >= '2015-01-01') & (df.abertura < '2016-01-01') & (df.descricao == bairro)].abertura.count()) + "\n")
    else:
        if bairro != "":
            outrosTotal[2] += df[(df.abertura >= '2017-01-01') & (df.descricao == bairro)].abertura.count()
            outrosTotal[1] += df[(df.abertura >= '2016-01-01') & (df.abertura < '2017-01-01') & (df.descricao == bairro)].abertura.count()
            outrosTotal[0] += df[(df.abertura >= '2015-01-01') & (df.abertura < '2016-01-01') & (df.descricao == bairro)].abertura.count()
            outrosAbertos[2] += df[(df.abertura >= '2017-01-01') & (df.descricao == bairro) & (df.situacao == "Aberto")].abertura.count()
            outrosAbertos[1] += df[(df.abertura >= '2016-01-01') & (df.abertura < '2017-01-01') & (df.descricao == bairro) & (df.situacao == "Aberto")].abertura.count()
            outrosAbertos[0] += df[(df.abertura >= '2015-01-01') & (df.abertura < '2016-01-01') & (df.descricao == bairro) & (df.situacao == "Aberto")].abertura.count()

print("Outros 2017: " +  str(outrosAbertos[2]/outrosTotal[2]))            
print("Outros 2016: " +  str(outrosAbertos[1]/outrosTotal[1]))            
print("Outros 2015: " +  str(outrosAbertos[0]/outrosTotal[0]))
# Out:
# Total chamados 2015: 827
# Total chamados 2016: 3674
# Total chamados 2017: 3194
#
# Fragata: 0.492957746479
# Fragata: 0.0474576271186
# Fragata: 0.02
#
# Três Vendas: 0.491031390135
# Três Vendas: 0.0786290322581
# Três Vendas: 0.0208333333333
#
# Centro: 0.339791356185
# Centro: 0.0765391014975
# Centro: 0.0
#
# Areal: 0.516129032258
# Areal: 0.047131147541
# Areal: 0.0
#
# Laranjal: 0.439461883408
# Laranjal: 0.0334728033473
# Laranjal: 0.0
#
# Outros 2017: 0.487320837927
# Outros 2016: 0.0523311132255
# Outros 2015: 0.00769230769231

# %% [markdown]
# O centro possui uma tava menor de chamados abertos do que os outros bairros. Isso se dá pq as pessoas do centro reclamam mais?
# Ou pq elas reclamam dos mesmos problemas?
# Ou pq tem uma quantidade mais de pessoas no centro?
# Os chamados estao relacionados a quantidade de pessoas que circulam em um lugar ou a quantidade de moradores?
# Ou pq a prefeitura direciona a maior parte dos serviços de manutenção para o centro?

# %%
for x in df[(df['descricao'] == "Areal") & (df['situacao'] == "Aberto") & (df['abertura'] >= "2017-01-01")].solicitacao:
    print(x + "\n")
# Out:
# PODA DE ARVORE NO ENDEREÇO, RUA HERBERT DE SOUZA, N°838, BAIRRO: AREAL.
#
# Rua Visconde de Taunay, próximo ao número 104, no Areal, está sofrendo com problemas de alagamento.
#
# Cidadã denuncia que na rua Mauricio Sirotski Sobrinho no entorno da RBS esta muito esburacada sem condições de transitar pede com urgência que seja tapado os mesmo pois já causou quedas de pessoas e de um ciclista de vido a quantidade de buracos.
#
# PODA DE ARVORE NO ENDEREÇO, BERNARDINO DOS SANTOS, N°83, BAIRRO: AREAL.
#
# Cidadão denuncia um vazamento de água na rua Antonio Augusto Pinto nº 83 bairro Fragata Já faz bastante tempo segundo ele os moradores já solicitaram no Sanep.
#
# Cidadã denuncia que na AV. Juscelino K.de Oliveira nº 2373 tem um salão de beleza Charme que esta largando toda a água com tinta de cabelo,todas as cores manchando a calçada, sem licença, sem alvará pede fiscalização urgente.
#
# Cidadão denuncia que na rua Fagundes Varela ao lado do nº 1261 Vasco Pires Areal o morador colocou um área para o lado da casa do vizinho e não colocou calha e que cada vez que chove alaga a casa do vizinho e mais outra casa ao lado pede fiscalização pois o mesmo não pediu autorização para construir a mesma.
#
# Poda de árvore na Rua Conselheiro Silveira  Martins, proximo ao num. 550, Areal.
#
# Esgoto entupido na rua Claudio Joaquim Piquet Ccoelho, travessa 1 número 29, bairro Bom Jesus, no Areal.
#
# Cidadã denuncia uma obra na Av. da Paz nº 169 no Bairro Areal segundo a cidadã estão fazendo um muro muito alto materiais na calçada perturbando os moradores pede fiscalização.
#
# TROCA DE LAMPADA NO ENDEREÇO, RUA RAFAEL PINTO BANDEIRA, ENTRE RUAS SÃO FRANCISCO DE PAULA E BENJAMIM GASTAL, N°303, BAIRRO: AREAL. OBS, CIDADÃO ALEGA QUE EXISTEM DOIS POSTES QUE ESTÃO A LUZ ACESSA PERMANENTEMENTE.
#
# CIDADÃO ALEGA QUE  O ENDEREÇO, RUA JOAO GOMES NOGUEIRA, N°861, BAIRRO: AREAL, EXISTI UMA RESIDENCIA NO QUAL O PROPRIETÁRIO EFETUA ACUMULO ENTULHOS E LIXOS (RESTO MOVEIS, FERROS VELHOS, MADEIRA E CASCOTES E RESÍDUOS DE LIXO) NO PATIO DA RESIDENCIA, OCASIONANDO NA PROLIFERAÇÃO DE MUITOS ANIMAIS PEÇONHENTOS, PRINCIPALMENTE RATOS. SOLICITA FISCALIZAÇÃO!
#

#
# TROCA DE LAMPADA NO ENDEREÇO, RUA DAVID CANABARRO, N°204, BAIRRO, AREAL.
#
# CIDADÃ ALEGA QUE NO ENDEREÇO, RUA ALBERTO PIMENTEL COM ESQUINA AV FERREIRA VIANA, BAIRRO, AREAL, EXISTIR UM TERRENO BALDIO COM ENORME ACUMULO DE LIXO, SERVINDO DE ESCONDERIJO PARA LADRÕES E ABRIGO PARA MORADORES DE RUA.
#
# NA RUA APOLINÁRIO PORTO ALEGRE EM FRENTE AO 492 EXISTE UM POSTE QUE NECESSITA DE REPARO NA ILUMINAÇÃO.
#
# NA RUA MARCILIO DIAS EM FRENTE AO 2284 EXISTEM 2 POSTES COM PROBLEMA NA ILUMINAÇÃO, É PEDIDO REPARO.
#
# CIDADÃO REIVINDICA DEVIDO ENDEREÇO, AV DOMINGOS DE ALMEIDA, ENTRE RUA REPUBLICA E RUA BENJAMIN GASTAUD, AO LADO DA CTMR, BAIRRO, AREAL, EXISTIR UM ESTABELECIMENTO, NO QUAL ESTA UTILIZANDO UM BALÃO INFLÁVEL NA CALÇADA, OCASIONANDO NA OBSTRUÇÃO DA MESMA.
#
# Cidadã pede ajustes na iluminação da rua Mascarenhas de Moraes. Segundo ela, entre as ruas Benjamim Gastal e Paul Harris, dos quatro postes somente três funcionam corretamente.
#
# Cidadã pede ajustes na iluminação da rua Mascarenhas de Moraes. Segundo ela, entre as ruas Benjamim Gastal e Paul Harris, dos quatro postes somente três funcionam corretamente.
#
# PATROLAMENTO DE RUA NO ENDEREÇO, RUA 2, N°300, BAIRRO, JARDIM EUROPA.
#
# CIDADÃ VEIO ATÉ A OUVIDORIA INFORMAR QUE A SUA IRMÃ CHAMADA IVONE CHARNAUD NOVAK, NECESSITA DE FRALDAS GERIÁTRICAS, NO MÊS DE MARÇO FOI PROMETIDO PARA O DIA 22 E SÓ FORAM ENTREGUES DIA 23 DE MAIO DE 2017, NO DIA 22 DE JUNHO A MESMA LIGOU PARA DAIANE E RUTH QUE SÃO FUNCIONÁRIA E ELAS ESTAVAM OCUPADAS, A MARCIANE QUE TAMBÉM É FUNCIONÁRIA, INFORMOU QUE NÃO HAVIAM FRALDAS DISPONÍVEIS, E QUE ERA PARA A CIDADÃ ESPERAR ATÉ O DIA 27 DE JUNHO, SALIENTOU QUE A CIDADÃ DEVERIA LIGAR PARA CONFIRMAR ANTES.
#
# É PEDIDO PATROLAMENTO NA RUA 1 DO DUNAS, MUITOS BURACOS E UM ENORME QUE IMPEDE A PASSAGEM, É PEDIDO PROVIDÊNCIA.
#
# PODA DE DUAS ARVORES NO ENDEREÇO, RUA BARATA RIBEIRO, N°84, BAIRRO, AREAL. SALIENTA QUE EM FRENTE A ESSE N° EXISTEM MAIS DUAS ARVORES NECESSITANDO DE PODA.
#
# PODA DE ARVORE NO ENDEREÇO, RUA BLAU NUNES, N°58, BAIRRO, AREAL.
#
# Cidadão solicita reposição de lampada na rua DR. Arnaldo Mesquita de Menezes nº 271 Bom Jesus Areal pede com urgência.
#
#
# É PEDIDO LIMPEZA DE VALETA NA RUA GAGO COUTINHO EM FRENTE AO Nº864 POIS A ÁGUA ESTÁ INVADINDO A RESIDÊNCIA.
#
# É SOLICITADO IMPLANTAÇÃO DE UM BRAÇO COM BOJO E LÂMPADA NA RUA MARCILIO DIAS ESQUINA 7 DE SETEMBRO E REPARO NA ILUMINAÇÃO NOS PRÓXIMOS 2 POSTES EM DIREÇÃO A PRAÇA 20 (DO OUTRO LADO DA RUA DO DETRAN).
#
# Cidadão solicita reposição de lampada na rua Gumercindo carvalho nº 470 esquina Com a Joaquim Alves da Fonseca  e também  Joaquim Alves da Fonseca nº 548 no bairro Obelisco Areal.
#
# Cidadão solicita reposição de lampada na rua Gravatai nº 405 quase esquina Barra do Ribeiro valverde Laranjal.
#
# TROCA DE LAMPADA NO ENDEREÇO, RUA DAVID DE CANABARRO, N°588, BAIRRO, AREAL / VILA SANTA LEOCÁDIA.
#
# TROCA DE DUAS LAMPADAS NO ENDEREÇO: TRAVESSA AUGOSTINO FERNANDES, N°703, BAIRRO: VASCO PIRES.
#
# Cidadão solicita reparos na Rua Humberto Lopes de Oliveira. Conforme relato, os buracos e o barro ainda continuam.
#
#  É SOLICITADO REPARO NA ILUMINAÇÃO PÚBLICA, NA RUA FRANCISCO SIMÕES EM FRENTE AO Nº 505 E 535
#
# É SOLICITADO REPARO NA ILUMINAÇÃO PÚBLICA, NA RUA IMPERADOR DOM PEDRO I, EM FRENTE AO Nº 3761 E 3777
#
# É SOLICITADO REPARO NA ILUMINAÇÃO PÚBLICA, NA RUA TENENTE LIRA EM FRENTE AO Nº403
#
# CIDADÃ SOLICITA RECOLHIMENTOS DE OFERENDAS DE UMBANDA NO ENDEREÇO, RUA GENERAL CÂMARA COM RUA ARMANDO FAGUNDES, BAIRRO: AREAL.
#
# É SOLICITADO REPARO NA ILUMINAÇÃO PÚBLICA, NA RUA ULYSSES BATINGA EM FRENTE AO Nº 1348 E 1490.
#
# CIDADÃ REIVINDICA DEVIDO ESTAR COM SOLICITAÇÃO PARA LIGAÇÃO DE ÁGUA EM SUA RESIDENCIA (RUA 1, N°510, LOTEAMENTO LIBERDADE / AREAL) NA AUTARQUIA SANEP HA MAIS DE DOIS MESES E ATÉ O MOMENTO NADA FOI FEITO. SOLICITA PROVIDENCIAS.
# (N° DE PROTOCOLO - S12717/2017)
#
# CIDADÃ ENTROU EM CONTATO PARA SOLICITAR MELHORA NO ATENDIMENTO DA FARMÁCIA MUNICIPAL, POIS O ATENDIMENTO ESTÁ MUITO PRECÁRIO, EM UMA HORA FORAM ATENDIDAS 3 FICHAS SOMENTE, NO DIA 31/08/2014 DAS 10 DA MANHA ATÉ AS 11 FORAM ATENDIDAS 3 PESSOAS, É PEDIDO PROVIDÊNCIAS.
#
# Cidadão denuncia um vazamento de água potável na AV. domingos de Almeida frente ao nº 578 esquina da Ortencio Rosa Areal pede com urgência.
#
# TROCA DE LAMPADA NO ENDEREÇO, RU
#
# Cidadão denuncia que na rua Dr. Urbano Garcia nº 86 bairro areal atras do Mac Donald tem um Colégio Adventista pois o mesmo esta fazendo obra e depositando material na calçada, e fazendo concreto na rua e que escorre caldo de cimento por toda a rua sendo que ali é uma ladeira os moradores estão sofrendo com aquela situação pede fiscalização urgência.
#
# Cidadã solicita reposição de lampada na AV. São Francisco de Paula nº 2530 Bairro Areal Próxima  a Auto Peças Castelhano
#
# CIDADÃO ALEGA QUE NO ENDEREÇO, RUA PEREIRA PASSOS, N°390, BAIRRO, AREAL , O PROPRIETÁRIO EFETUA A CRIAÇÃO DE CERCA DE 50 GALINHAS E 03 CÃES NO PATIO DA RESIDENCIA, OCASIONANDO TRANSTORNOS AOS MORADORES AO REDOR, COM RELAÇÃO AO MAU CHEIRO DAS VEZES QUE FICAM EXPOSTAS. SOLICITA FISCALIZAÇÃO!
#
# Cidadão solicita limpeza em alguns pontos da Domingos de Almeida. Conforme relato, algumas partes da ciclovia e também os canteiros estão repletos de mato alto, mesmo sem as obras concluídas.
#
# Cidadão solicita ajustes na rua Fagundes Varella, Luiz Alves Pereira e Magda da Costa, no Vasco Pires.
#
# Cidadã solicita ajustes na iluminação da rua Monsenhor Queiroz no Bairro Areal entre os números 599 e 607. Conforme relato, são dois postes.
#
# NA RUA LUIZ ALVES PEREIRA EM FRENTE AO 147, EXISTE UM POSTE QUE NECESSITA DE RAPARO NA ILUMINAÇÃO PÚBLICA.
#
# Cidadão denuncia que na rua Capitão Antoninho Soares nº 94 tem uma obra irregular sem licenciamento, e que esta depositando material na calçada e parte da rua causando transtorno aos moradores, pede fiscalização urgente pois e uma obra de três andares e vai demorar algum tempo para ser construída e tem causado alagamento devido aos materiais.
#
# PODA DE ARVORE (AMOREIRA) NO ENDEREÇO, RUA ANTONIO DOS ANJOS COM ESQUINA AV J.K DE OLIVEIRA, BAIRRO, AREAL.
#
# Cidadão denuncia areia e brita na Calçada da rua Pedro Santos Teixeira, a Direita de quem entra no loteamento. Segundo ele, já foi solicitado ajustes aos responsáveis pela obra, só que o problema não é solucionado.
#
# TROCA DE LAMPADA NO ENDEREÇO, AV. DOMINGOS DE ALMEIDA, N°1908, BAIRRO, AREAL.
#
# CIDADÃ REIVINDICA DEVIDO O NUMERO DE SEU SID (DOCUMENTO QUE COMPRAVA A A SUA LICENÇA PARA ISENÇÃO NO TRASPORTE COLETIVO) TER SIDO REDUZIDO BRUSCAMENTE E COM A ALTERAÇÃO DA LEGISLAÇÃO RECENTEMENTE A SUA ISENÇÃO FOI NEGADA SENDO QUE MESMA POSSUI 63 ANOS DE IDADE. SALIENTA QUE TEM QUE SE DESLOCAR CERTA DE 4 VEZES AO CENTRO DURANTE TODA SEMANA PARA REALIZAÇÃO DE CONSULTAS, O QUAL ESTA IMPOSSIBILITADA DEVIDO A PERCA DE ISENÇÃO.
#
# RECOLHIMENTO DE GALHOS ARVORE NO ENDEREÇO, RUA APOLINÁRIO PORTO ALEGRE, UBS AREAL 1, BAIRRO, AREAL.
#
# NA RUA LUIS ALVES PEREIRA ENTRE O Nº 633 E 635 EXISTE UM POSTE QUE NECESSITA DE REPARO NA ILUMINAÇÃO PÚBLICA, NO AREAL.
#
# Cidadã denuncia que hoje pela manhã esteve no posto Um (1) do Areal e tentou fazer um teste rápido de hepatite e não  conseguiu pois a enfermeira Cristiane disse que não tinha tempo para atender pois tinha muitos documentos para preencher, também pediu para marcar um pre câncer e a mesma respondeu que teria que agendar em outro dia. Pede melhorias no atendimento o nome dela Silvia o tel. para contato 984278560.
#
# Cidadã denuncia que no Passeio UM nº 662 do Jardim das Tradições Três Vendas tem um esgoto entupido a muito tempo pede com urgência pois já Solicitou no SANEP mas até agora nada foi feito.
#
# Cidadã solicita reposição de lampada na rua Barros Cassal nº 297 Areal. Cidadã idosa e mora sozinha e esta muito escuro no local e a mesma não consegue sair de casa devido a escuridão.
#
# Cidadão solicita reposição de lampada nº 340 Bairro Areal segundo o cidadão a lampada esta acesa mas esta virada para o lado e braço meio pendurado.
#
# LIMPEZA URBANA NO ENDEREÇO, RUA APOLINARIO PORTO ALEGRE COM ESQUINA RUA RAFAEL PINTO BANDEIRA, BAIRRO, AREAL.
#
# PODA DE ARVORE NO ENDEREÇO, RUA GUARARAPES, N°223, BAIRRO, AREAL.
#
# Cidadão solicita limpeza das valetas na rua Magda da Costa até a rua Três no Vasco Pires pede com urgência pois a rua esta alagada e a água esta entrando nas casas.
#
# NA RUA JK DE OLIVEIRA, ESQUINA COM PRACINHA HORTÊNCIO ROSA EXISTE UM ESTABELECIMENTO CHAMADO PACMAN, ONDE MUITOS CARROS ESTACIONAM E TRANCAM A PASSAGEM, ALÉM DE FAZEREM MUITA SUJEIRA, ESTABELECIMENTO APARENTEMENTE SEM ALVARÁ, É PEDIDO FISCALIZAÇÃO E PROVIDÊNCIA.
#
# NA RUA JK DE OLIVEIRA, ESQUINA COM PRACINHA HORTÊNCIO ROSA EXISTE UM ESTABELECIMENTO CHAMADO PACMAN, ONDE MUITOS CARROS ESTACIONAM E TRANCAM A PASSAGEM, ALÉM DE FAZEREM MUITA SUJEIRA, ESTABELECIMENTO APARENTEMENTE SEM ALVARÁ, É PEDIDO FISCALIZAÇÃO E PROVIDÊNCIA.

# %%
for x in df.tipo.unique():
    print(x)
# Out:
# Obra irregular
# Entulho na calçada/ Via pública
# Pendência de exame
# Unidade Básica de Saúde
# Condição sanitária irregular
# Maus tratos a animais
# Poda e Retirada de Árvore
# Falta de rampa de acessibilidade
# Rua esburacada
# Estabelecimento sem alvará
# Ocupação Irregular de Área Púlica
# Terreno baldio
# Não cumprimento de itinerários
# Emissão de fumaça preta e gazes poluentes.
# Iluminação Pública Irregular
# Estacionamento Irregular
# Vazamento de água potável
# Lei de Acesso a Informação
# Poluição Sonora
# Esgoto a céu aberto
# Aterro sanitário irregular
# Mau atendimento em escolas
# Semáforo Danificado
# Bueiro Entupido
# Estabelecimento Irregular
# Falta de água
# Contêiners
# Mau atendimento na saúde
# Prefeitura / Elogios
# Carnaval
# Regularização fundiária
# Ponto de alagamentos
# IPTU
# Foco de Dengue
# Rivindicação Ouvidoria
# Obstrução de calçada.
# Calçada irregular
# Faixa de pedestre inexistente
# Sinalização irregular
# Criação de animais em condições precárias
# UBS Sem médico.
# Guarda Municipal
# Ponto de ônibus danificado.
# Lixeira quebrada / Contêiner
# Saúde da Família
# Desmatamento irregular
# Ciclovia/faixa  mal sinalizada
# Limpeza Urbana
# Mau atendimento SERTEL
# Mau atendimento sanep
# Recolhimento de entulho
# Mau atendimento Vigilância Sanitária
# Imóvel abandonado
# Abrigos de ônibus
# Infestação de roedores
# Saúde bucal
# Buraco na via NÃO pavimentada
# Passagem de transporte coletivo.
# Desobstrução de galeria
# Mau atendimento SQA
# Agressão ao meio ambiente
# Tampa de galeria
# Bloqueio de via pública
# CRAS
# Veiculo abandonado.
# Projetos da cidade.
# Praças
# Depredação de Patrimônio Público
# Buraco na via pavimentada
# Placa de sinalização danificada
# Patrimônio Público
# Comercialização irregular
# Colocação de ponte "COLONIA"
# Placas / Logradouros
# Animais de porte grande soltos
# Ruas - Colonia
# Ônibus danificado
# Meu atendimento cadastro único
# Mau atendimento SJSS
# LIMPEZA DE VALETAS
# Perturbação de Sossego
# Colocação de saibro.
# Sugestões
# Distritos
# Mercado Central
# Concursos SGAF
# Mau atendimento SHRF
# Fumacê
# Mau atendimento SGAF
# Praia suja
# Estabelecimento sem saída de emergência
# Falta de segurança
# Mau atendimento SGCMU
# Estabelecimento sem nota fiscal
# Fechamento de canteiro central
# ITBI
# Fiação irregular

# %%
for x in df[df["tipo"] == "Prefeitura / Elogios"].solicitacao:
    print(x  + "\n")
# Out:
# Moradora da Rua 20, nº 2866, elogiou a gestão atual e agradeceu a presença deles no bairro.
#
# CIDADÃO REIVINDICA DEVIDO O RECADASTRAMENTO DO PONTO BIOMÉTRICO QUE SENDO FEITO NO 7º DISTRITO  NÃO TER SIDO DIVULGADO UM CRONOGRAMA PARA OS DEMAIS DISTRITOS. TENDO ASSIM, QUE OS MORADORES SE DESLOCAREM AO CENTRO DA CIDADE PARA  EFETUAR O MESMO, ARCANDO COM CUSTO ALTO DE PASSAGEM!
#
# tetstestetstetstetstets
#
# Cidadão alega que no cine pelotas esta havendo um descaso com a população, devido a falta de ficha, pois a mesma se dirigiu ao setor para perguntar uma informação e simplesmente foi mal tratada pelo funcionário da recepção, que nem quis atende-la pelo fato da falta de ficha!
#
# CIDADÃO ALEGA QUE EM SEU ENDEREÇO: RUA LOBO DA COSTA, N°543, BAIRRO, CENTRO, TODOS OS DIAS UM VEICULO DA PREFEITURA (PLACA IPE - 6732) ESTA PARADO EM CIMA DA RAMPA DE ACESSO A SUA RESIDENCIA OCASIONANDO NA OBSTRUÇÃO MESMA E, IMPOSSIBILITANDO O ACESSO DO MESMO A SUA PRÓPRIA RESIDENCIA. SALIENTA QUE O MOTORISTA FOI EXTREMAMENTE AGRESSIVO COM DEMANDANTE E, ISSO TUDO COMEÇOU A ACONTECER DEVIDO A SGCMU TER SE INSTALADO AO LADO DE SUA RESIDENCIA.
#
# teste do sistema com a Coipel
#
# Obriga senhor Eduardo Leite
#
# CIDADÃO GOSTARIA DE ELOGIAR O ATENDIMENTO DO ENFERMEIRO GEOVANE QUE TRABALHA NO POSTO DA SALGADO FILHO.
#
# CIDADÃ REIVINDICA DEVIDO TER COMPARECIDO NO PROCON NO DIA 11/10 POR VOLTA DAS 13H E 45MIN PARA EFETUAR UMA RECLAMAÇÃO E TER ENCONTRADO O MESMO COM AS PORTAS FECHADAS, SENDO QUE, PELO HORARIO DE EXPEDIENTE EXPOSTO A AUTARQUIA DEVERIA FECHAR AS 14H.
#
# Elogio para o SANEP
# Boa tarde:
#
# Elogio o pronto atendimento, educação e a conduta exemplar do servidor do Sanep, Sr. Nelcio, pois, pois, após tentar atendimento dos telefones disponíveis, sem sucesso, fui por ele atendido prestando-me todas as informações. Parabéns Sr. NELCIO - Parabéns SANEP.
# Atenciosamente
#
# Fernando Monte.
# PS: Solicito a gentileza do funcionário encarregado da Ouvidoria, encaminhar à quem responsável.
#
# ydgaidfgaidshgdhdsohdsodhaspdahdsajpasfda
#
# Boa noite, estou com uma dúvida, estou estudando para o concurso da prefeitura,e ao estudar estatuto dos servidores, nº 3008, não consegui identificar qual regime de aposentadoria, então gostaria de saber qual regime de aposentadoria os servidores e funcionários, devem obedecer. Obrigada.
#
# Olá, gostaria de saber o seguinte: Os servidores da prefeitura possuem algum tipo de adicional? Como por exemplo, vale alimentação ou transporte? Obrigado.
#
# Boa noite, gostaria de saber como faço pra conseguir a legislação do novo concurso que acabou de sair??
#
# Olá, Gostaria de saber sobre o cargo de oficial administrativo. No edital do concurso vigente consta a remuneração do cargo por volta de 937. Está correto? O cargo não percebe vantagens adicionais? Está bem distante da remuneração de outras prefeituras. Obrigado pela atenção
#
# Gostaria de saber quanto ganha, no total sem os descontos, a função de ARTÍFICE.
#
# Olá! Meu nome é charles misael leitzke, eu gostaria de saber com vocÊs se estão tendo algum concurso que se faça para contratação de pessoal em alguma área em vossa cidade. Ou se têm algum centro de direcionamento a empregadores. Obrigado!
#
# Boa Tarde, Estou com problema no site da Giss Online para incluir as NFs para recolhimento do ISSQN. Tenho esse problema todo o mês, mas consigo incluir, mas esse mês dá erro na pg, ou fica tudo em branco.
#
# Bom dia, poderiam me informar, por gentileza, o número de telefonistas contratadas pela Prefeitura? Obrigado
#
# bom dia ,preciso de informacoes sobre o concurso publico cargo de agente fiscal: gratificaçoes,vale alimentaçao,vale transporte=valor,grato no aguardo
#
# Prezados, Gostaria de saber em qual arquivo devo buscar as leis municipais. Há documentos no Portal que não estão disponíveis ou estão apenas parcialmente.
#
# Prezados
# Bom dia!
#
# No edital do concurso que está aberto consta salário de 937 reais mais complementos legais,quanto seria isto?
#
# Atenciosamente
#
# Igor Alexandre
# Técnico em segurança do trabalho
#
# Olá bom dia, gostaria de saber como me inscrevo no programa de habitação, sou portador de doença crônica em tratamento?
#
# Olá, gostaria de uma informação sobre o concurso publico da prefeitura. Quero saber se quem se declarou desempregado precisa autenticar o anexo VII junto com a carteira de trabalho,e se o anexo pode ser preenchido a mão. Obrigada.
