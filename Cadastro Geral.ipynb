# %%
tt
# Out:
#     tipo_unidade                         orgao  \
# 0        Escolas  S. M. de Educação e Desporto
# 1        Escolas  S. M. de Educação e Desporto
# 2        Escolas  S. M. de Educação e Desporto
# 3        Escolas  S. M. de Educação e Desporto
# 4        Escolas  S. M. de Educação e Desporto
# 5        Escolas  S. M. de Educação e Desporto
# 6        Escolas  S. M. de Educação e Desporto
# 7        Escolas  S. M. de Educação e Desporto
# 8        Escolas  S. M. de Educação e Desporto
# 9        Escolas  S. M. de Educação e Desporto
# 10       Escolas  S. M. de Educação e Desporto
# 11       Escolas  S. M. de Educação e Desporto
# 12       Escolas  S. M. de Educação e Desporto
# 13       Escolas  S. M. de Educação e Desporto
# 14       Escolas  S. M. de Educação e Desporto
# 15       Escolas  S. M. de Educação e Desporto
# 16       Escolas  S. M. de Educação e Desporto
# 17       Escolas  S. M. de Educação e Desporto
# 18       Escolas  S. M. de Educação e Desporto
# ...

# %%
print("Total: " + str(len(geral['tipo_unidade'].unique())) + '\n')
for x in geral['tipo_unidade'].unique():
    print(x)
    print(geral[geral['tipo_unidade'] == x]['bairro'].value_counts())
    print('\n\n')
# Out:
# Total: 7
#
# Escolas
# Três Vendas    22
# Zona Rural     20
# Fragata        15
# Centro         14
# Areal          14
# Laranjal        3
# Name: bairro, dtype: int64
#
#
#
# Pontes
# Zona Rural    34
# Centro         1
#                1
# Name: bairro, dtype: int64
#
#
#
# Praças
# Três Vendas    24
# Centro         15
# Laranjal       14
# Fragata        11
# Areal           9
# Zona Rural      4
# Name: bairro, dtype: int64
#
#
#
# Saneamento
# Centro         13
# Laranjal        9
# Três Vendas     9
# Fragata         8
# Areal           5
# Zona Rural      4
#                 1
# Name: bairro, dtype: int64
#
#
#
# Saúde e Assistência Social
# Centro         13
# Três Vendas     6
# Areal           5
# Fragata         2
# Zona Rural      1
# Name: bairro, dtype: int64
#
#
#
# Secretarias, Empresas e Autarquias
# Centro         42
# Zona Rural      9
# Areal           9
# Fragata         5
# Três Vendas     3
# Laranjal        1
#                 1
# ...

# %%
geral[geral['orgao'] == "SANEP"][['nome', 'bairro']]
# Out:
#                                                 nome       bairro
# 201              Aterro Controlado e Balança do Lixo  Três Vendas
# 202                  Bomba de Drenagem Pluvial Anglo       Centro
# 203              Bomba de Drenagem Pluvial Castilhos       Centro
# 204              Bomba de Drenagem Pluvial Doquinhas       Centro
# 205            Bomba de Drenagem Pluvial Farroupilha      Fragata
# 206                  Bomba de Drenagem Pluvial Leste
# 207                Bomba de Drenagem Pluvial Olvebra      Fragata
# 208        Bomba de Drenagem Pluvial Pontal da Barra     Laranjal
# 209           Bomba de Drenagem Pluvial Simões Lopes       Centro
# 210                                        Booster 1       Centro
# 211                                        Booster 2        Areal
# 212            Estação de Tratamento de Água Moreira   Zona Rural
# 213      Estação de Tratamento de Água Santa Bárbara  Três Vendas
# ...
